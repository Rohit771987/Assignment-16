# %% [markdown]
# # The dataset contains 36733 instances of 11 sensor measures aggregated over one hour (by means of average or sum) from a gas turbine.
# The Dataset includes gas turbine parameters (such as Turbine Inlet Temperature and Compressor Discharge pressure) in addition to the ambient variables.
#
#
#
# Problem statement: predicting turbine energy yield (TEY) using ambient variables as features.
#
#
#
# Attribute Information:
#
# The explanations of sensor measurements and their brief statistics are given below.
#
# * Variable (Abbr.) Unit Min Max Mean
# * Ambient temperature (AT) C â€“6.23 37.10 17.71
# * Ambient pressure (AP) mbar 985.85 1036.56 1013.07
# * Ambient humidity (AH) (%) 24.08 100.20 77.87
# * Air filter difference pressure (AFDP) mbar 2.09 7.61 3.93
# * Gas turbine exhaust pressure (GTEP) mbar 17.70 40.72 25.56
# * Turbine inlet temperature (TIT) C 1000.85 1100.89 1081.43
# * Turbine after temperature (TAT) C 511.04 550.61 546.16
# * Compressor discharge pressure (CDP) mbar 9.85 15.16 12.06
# * Turbine energy yield (TEY) MWH 100.02 179.50 133.51
# * Carbon monoxide (CO) mg/m3 0.00 44.10 2.37
# * Nitrogen oxides (NOx) mg/m3 25.90 119.91 65.29

# %% [markdown]
# ###  importing the necessary packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ###  import the dataset

# %%
data = pd.read_csv('gas_turbines.csv')

# %% [markdown]
# ###  EDA process

# %%
data.head()
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %% [markdown]
# ###  Change the posision 'TEY' column

# %%
tey = data['TEY']
# Drop the TYE column in data set
data.drop('TEY', axis =1, inplace = True)

# %%
data.insert(10, 'y', tey)

# %%
data1 = data.rename({'y':'TEY'}, axis = 1)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   CDP     15039 non-null  float64
#  8   CO      15039 non-null  float64
#  9   NOX     15039 non-null  float64
#  10  TEY     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %% [markdown]
# ###### Corelation matrix

# %%
data1.corr()
# Out:
#             AT        AP        AH      AFDP      GTEP       TIT       TAT  \
# AT    1.000000 -0.412953 -0.549432 -0.099333 -0.049103  0.093067  0.338569
# AP   -0.412953  1.000000  0.042573  0.040318  0.078575  0.029650 -0.223479
# AH   -0.549432  0.042573  1.000000 -0.119249 -0.202784 -0.247781  0.010859
# AFDP -0.099333  0.040318 -0.119249  1.000000  0.744251  0.627254 -0.571541
# GTEP -0.049103  0.078575 -0.202784  0.744251  1.000000  0.874526 -0.756884
# TIT   0.093067  0.029650 -0.247781  0.627254  0.874526  1.000000 -0.357320
# TAT   0.338569 -0.223479  0.010859 -0.571541 -0.756884 -0.357320  1.000000
# CDP  -0.100705  0.131198 -0.182010  0.727152  0.993784  0.887238 -0.744740
# CO   -0.088588  0.041614  0.165505 -0.334207 -0.508259 -0.688272  0.063404
# NOX  -0.600006  0.256744  0.143061 -0.037299 -0.208496 -0.231636  0.009888
# TEY  -0.207495  0.146939 -0.110272  0.717995  0.977042  0.891587 -0.720356
#
#            CDP        CO       NOX       TEY
# AT   -0.100705 -0.088588 -0.600006 -0.207495
# AP    0.131198  0.041614  0.256744  0.146939
# AH   -0.182010  0.165505  0.143061 -0.110272
# AFDP  0.727152 -0.334207 -0.037299  0.717995
# GTEP  0.993784 -0.508259 -0.208496  0.977042
# TIT   0.887238 -0.688272 -0.231636  0.891587
# TAT  -0.744740  0.063404  0.009888 -0.720356
# CDP   1.000000 -0.520783 -0.169103  0.988473
# CO   -0.520783  1.000000  0.316743 -0.541751
# NOX  -0.169103  0.316743  1.000000 -0.102631
# TEY   0.988473 -0.541751 -0.102631  1.000000

# %%
data1.describe()
# Out:
#                  AT           AP            AH          AFDP          GTEP  \
# count  15039.000000  15039.00000  15039.000000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174      4.200294     25.419061
# std        7.574323      6.41076     13.793439      0.760197      4.173916
# min        0.522300    985.85000     30.344000      2.087400     17.878000
# 25%       11.408000   1008.90000     69.750000      3.723900     23.294000
# 50%       18.186000   1012.80000     82.266000      4.186200     25.082000
# 75%       23.862500   1016.90000     90.043500      4.550900     27.184000
# max       34.929000   1034.20000    100.200000      7.610600     37.402000
#
#                 TIT           TAT           CDP            CO           NOX  \
# count  15039.000000  15039.000000  15039.000000  15039.000000  15039.000000
# mean    1083.798770    545.396183     12.102353      1.972499     68.190934
# std       16.527806      7.866803      1.103196      2.222206     10.470586
# min     1000.800000    512.450000      9.904400      0.000388     27.765000
# 25%     1079.600000    542.170000     11.622000      0.858055     61.303500
# 50%     1088.700000    549.890000     12.025000      1.390200     66.601000
# 75%     1096.000000    550.060000     12.578000      2.160400     73.935500
# max     1100.800000    550.610000     15.081000     44.103000    119.890000
#
#                 TEY
# count  15039.000000
# mean     134.188464
# std       15.829717
# min      100.170000
# 25%      127.985000
# 50%      133.780000
# 75%      140.895000
# max      174.610000

# %% [markdown]
# ###  train test split

# %%
data3 = data1.drop(['AT','AP','AH','CO','NOX'],axis = 1)

# %%
data3.head()
# Out:
#      AFDP    GTEP     TIT     TAT     CDP     TEY
# 0  3.5000  19.663  1059.2  550.00  10.605  114.70
# 1  3.4998  19.728  1059.3  550.00  10.598  114.72
# 2  3.4824  19.779  1059.4  549.87  10.601  114.71
# 3  3.4805  19.792  1059.6  549.99  10.606  114.72
# 4  3.4976  19.765  1059.7  549.98  10.612  114.72

# %%
array = data3.values

# %%
x = array[:,:-1]
y = array[:,-1]

# %%
print(x)
# Out:
# [[   3.5      19.663  1059.2     550.       10.605 ]
#  [   3.4998   19.728  1059.3     550.       10.598 ]
#  [   3.4824   19.779  1059.4     549.87     10.601 ]
#  ...
#  [   3.477    19.53   1037.7     537.32     10.483 ]
#  [   3.4486   19.377  1043.2     541.24     10.533 ]
#  [   3.4275   19.306  1049.9     545.85     10.583 ]]

# %%
print(y)
# Out:
# [114.7  114.72 114.71 ... 110.19 110.74 111.58]

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y, test_size =0.3)

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

sc.fit(x_train)

x_train_std = sc.transform(x_train)

sc.fit(y_train.reshape(-1, 1))
# Out:
# StandardScaler()

# %%
y_train_std = sc.transform(y_train.reshape(-1,1))

# %%
print('Shape of x_train: ', x_train.shape)
print('Shape of x_test: ', x_test.shape)
print('Shape of y_train: ', y_train.shape)
print('Shape of y_test: ', y_test.shape)
# Out:
# Shape of x_train:  (10527, 5)
# Shape of x_test:  (4512, 5)
# Shape of y_train:  (10527,)
# Shape of y_test:  (4512,)

# %% [markdown]
# ### Artificial Neural Network Model

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
# create model
model = Sequential()
model.add(Dense(10, input_dim=5, kernel_initializer='he_uniform', activation='relu'))
model.add(Dense(6, kernel_initializer='he_uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='he_uniform', activation='linear'))

## compile model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse'])

## fit the model 
model.fit(x_train,y_train, epochs=100, batch_size=40)
# Out:
# Epoch 1/100
# 264/264 [==============================] - 1s 715us/step - loss: 19757.5957 - mse: 19757.5957
# Epoch 2/100
# 264/264 [==============================] - 0s 524us/step - loss: 181.2208 - mse: 181.2208
# Epoch 3/100
# 264/264 [==============================] - 0s 520us/step - loss: 175.3093 - mse: 175.3093
# Epoch 4/100
# 264/264 [==============================] - 0s 520us/step - loss: 171.7128 - mse: 171.7128
# Epoch 5/100
# 264/264 [==============================] - 0s 505us/step - loss: 167.6316 - mse: 167.6316
# Epoch 6/100
# 264/264 [==============================] - 0s 522us/step - loss: 162.7580 - mse: 162.7580
# Epoch 7/100
# 264/264 [==============================] - 0s 589us/step - loss: 156.9752 - mse: 156.9752
# Epoch 8/100
# 264/264 [==============================] - 0s 517us/step - loss: 150.5169 - mse: 150.5169
# Epoch 9/100
# 264/264 [==============================] - 0s 546us/step - loss: 142.8681 - mse: 142.8681
# Epoch 10/100
# 264/264 [==============================] - 0s 514us/step - loss: 134.3066 - mse: 134.3066
# Epoch 11/100
# 264/264 [==============================] - 0s 520us/step - loss: 124.8357 - mse: 124.8357
# Epoch 12/100
# 264/264 [==============================] - 0s 670us/step - loss: 114.2721 - mse: 114.2721
# Epoch 13/100
# 264/264 [==============================] - 0s 1ms/step - loss: 102.5112 - mse: 102.5112
# Epoch 14/100
# 264/264 [==============================] - 0s 1ms/step - loss: 90.0062 - mse: 90.0062
# Epoch 15/100
# 264/264 [==============================] - 0s 1ms/step - loss: 76.8058 - mse: 76.8058
# Epoch 16/100
# 264/264 [==============================] - 0s 1ms/step - loss: 63.5065 - mse: 63.5065
# Epoch 17/100
# 264/264 [==============================] - 0s 921us/step - loss: 50.0117 - mse: 50.0117
# Epoch 18/100
# 264/264 [==============================] - 0s 635us/step - loss: 37.9943 - mse: 37.9943
# Epoch 19/100
# 264/264 [==============================] - 0s 561us/step - loss: 27.6931 - mse: 27.6931
# Epoch 20/100
# 264/264 [==============================] - 0s 599us/step - loss: 19.5001 - mse: 19.5001
# Epoch 21/100
# 264/264 [==============================] - 0s 834us/step - loss: 13.9116 - mse: 13.9116
# Epoch 22/100
# 264/264 [==============================] - 0s 802us/step - loss: 10.3969 - mse: 10.3969
# Epoch 23/100
# 264/264 [==============================] - 0s 592us/step - loss: 8.5904 - mse: 8.5904
# Epoch 24/100
# 264/264 [==============================] - 0s 677us/step - loss: 7.7610 - mse: 7.7610
# Epoch 25/100
# 264/264 [==============================] - 0s 761us/step - loss: 7.6505 - mse: 7.6505
# Epoch 26/100
# 264/264 [==============================] - 0s 603us/step - loss: 7.4675 - mse: 7.4675
# Epoch 27/100
# 264/264 [==============================] - 0s 527us/step - loss: 7.4435 - mse: 7.4435
# Epoch 28/100
# 264/264 [==============================] - 0s 554us/step - loss: 7.4884 - mse: 7.4884
# Epoch 29/100
# 264/264 [==============================] - 0s 630us/step - loss: 7.4256 - mse: 7.4256
# Epoch 30/100
# 264/264 [==============================] - 0s 705us/step - loss: 7.4476 - mse: 7.4476
# Epoch 31/100
# 264/264 [==============================] - 0s 755us/step - loss: 7.4297 - mse: 7.4297
# Epoch 32/100
# 264/264 [==============================] - 0s 735us/step - loss: 7.5347 - mse: 7.5347
# Epoch 33/100
# 264/264 [==============================] - 0s 1ms/step - loss: 7.5628 - mse: 7.5628
# Epoch 34/100
# 264/264 [==============================] - 0s 2ms/step - loss: 7.4737 - mse: 7.4737
# Epoch 35/100
# 264/264 [==============================] - 0s 1ms/step - loss: 7.5372 - mse: 7.5372
# Epoch 36/100
# 264/264 [==============================] - 0s 1ms/step - loss: 7.4840 - mse: 7.4840
# Epoch 37/100
# 264/264 [==============================] - 0s 946us/step - loss: 7.3894 - mse: 7.3894
# Epoch 38/100
# 264/264 [==============================] - 0s 576us/step - loss: 7.4015 - mse: 7.4015
# Epoch 39/100
# 264/264 [==============================] - 0s 527us/step - loss: 7.4445 - mse: 7.4445
# Epoch 40/100
# 264/264 [==============================] - 0s 1ms/step - loss: 7.5108 - mse: 7.5108
# Epoch 41/100
# 264/264 [==============================] - 0s 1ms/step - loss: 7.6145 - mse: 7.6145
# Epoch 42/100
# 264/264 [==============================] - 0s 1ms/step - loss: 7.5031 - mse: 7.5031
# Epoch 43/100
# 264/264 [==============================] - 0s 1ms/step - loss: 7.8579 - mse: 7.8579
# Epoch 44/100
# 264/264 [==============================] - 0s 2ms/step - loss: 7.7652 - mse: 7.7652
# Epoch 45/100
# 264/264 [==============================] - 0s 557us/step - loss: 7.5731 - mse: 7.5731
# Epoch 46/100
# 264/264 [==============================] - 0s 550us/step - loss: 7.5049 - mse: 7.5049
# Epoch 47/100
# 264/264 [==============================] - 0s 565us/step - loss: 7.7372 - mse: 7.7372
# Epoch 48/100
# 264/264 [==============================] - 0s 580us/step - loss: 7.4351 - mse: 7.4351
# Epoch 49/100
# 264/264 [==============================] - 0s 942us/step - loss: 7.5677 - mse: 7.5677
# Epoch 50/100
# 264/264 [==============================] - 0s 757us/step - loss: 7.7068 - mse: 7.7068
# Epoch 51/100
# 264/264 [==============================] - 0s 583us/step - loss: 7.4730 - mse: 7.4730
# Epoch 52/100
# 264/264 [==============================] - 0s 580us/step - loss: 7.2825 - mse: 7.2825
# Epoch 53/100
# 264/264 [==============================] - 0s 572us/step - loss: 7.3109 - mse: 7.3109
# Epoch 54/100
# 264/264 [==============================] - 0s 535us/step - loss: 7.6023 - mse: 7.6023
# Epoch 55/100
# 264/264 [==============================] - 0s 561us/step - loss: 7.4317 - mse: 7.4317
# Epoch 56/100
# 264/264 [==============================] - 0s 535us/step - loss: 7.4769 - mse: 7.4769
# Epoch 57/100
# 264/264 [==============================] - 0s 523us/step - loss: 7.6191 - mse: 7.6191
# Epoch 58/100
# 264/264 [==============================] - 0s 523us/step - loss: 7.1668 - mse: 7.1668
# Epoch 59/100
# 264/264 [==============================] - 0s 516us/step - loss: 7.4874 - mse: 7.4874
# Epoch 60/100
# 264/264 [==============================] - 0s 916us/step - loss: 7.4895 - mse: 7.4895
# Epoch 61/100
# 264/264 [==============================] - 1s 2ms/step - loss: 7.3485 - mse: 7.3485
# Epoch 62/100
# 264/264 [==============================] - 1s 2ms/step - loss: 7.5001 - mse: 7.5001
# Epoch 63/100
# 264/264 [==============================] - 0s 1ms/step - loss: 7.3722 - mse: 7.3722
# Epoch 64/100
# 264/264 [==============================] - 0s 1ms/step - loss: 7.3838 - mse: 7.3838
# Epoch 65/100
# 264/264 [==============================] - 0s 1ms/step - loss: 7.3668 - mse: 7.3668
# Epoch 66/100
# 264/264 [==============================] - 0s 993us/step - loss: 7.4614 - mse: 7.4614
# Epoch 67/100
# 264/264 [==============================] - 0s 940us/step - loss: 7.2576 - mse: 7.2576
# Epoch 68/100
# 264/264 [==============================] - 0s 1ms/step - loss: 7.2050 - mse: 7.2050
# Epoch 69/100
# 264/264 [==============================] - 0s 1ms/step - loss: 7.5893 - mse: 7.5893
# Epoch 70/100
# 264/264 [==============================] - 0s 1ms/step - loss: 7.4824 - mse: 7.4824
# Epoch 71/100
# 264/264 [==============================] - 0s 607us/step - loss: 7.3673 - mse: 7.3673
# Epoch 72/100
# 264/264 [==============================] - 0s 535us/step - loss: 7.2987 - mse: 7.2987
# Epoch 73/100
# 264/264 [==============================] - 0s 547us/step - loss: 7.5238 - mse: 7.5238
# Epoch 74/100
# 264/264 [==============================] - 0s 546us/step - loss: 7.3059 - mse: 7.3059
# Epoch 75/100
# 264/264 [==============================] - 0s 658us/step - loss: 7.3778 - mse: 7.3778
# Epoch 76/100
# 264/264 [==============================] - 0s 808us/step - loss: 7.0042 - mse: 7.0042
# Epoch 77/100
# 264/264 [==============================] - 0s 937us/step - loss: 7.2865 - mse: 7.2865
# Epoch 78/100
# 264/264 [==============================] - 0s 935us/step - loss: 7.3705 - mse: 7.3705
# Epoch 79/100
# 264/264 [==============================] - 0s 709us/step - loss: 7.2792 - mse: 7.2792
# Epoch 80/100
# 264/264 [==============================] - 0s 810us/step - loss: 7.1924 - mse: 7.1924
# Epoch 81/100
# 264/264 [==============================] - 0s 677us/step - loss: 7.1551 - mse: 7.1551
# Epoch 82/100
# 264/264 [==============================] - 0s 580us/step - loss: 7.2167 - mse: 7.2167
# Epoch 83/100
# 264/264 [==============================] - 0s 550us/step - loss: 7.0570 - mse: 7.0570
# Epoch 84/100
# 264/264 [==============================] - 0s 596us/step - loss: 7.3822 - mse: 7.3822
# Epoch 85/100
# 264/264 [==============================] - 0s 880us/step - loss: 7.3074 - mse: 7.3074
# Epoch 86/100
# 264/264 [==============================] - 0s 1ms/step - loss: 7.3354 - mse: 7.3354
# Epoch 87/100
# 264/264 [==============================] - 0s 770us/step - loss: 7.3977 - mse: 7.3977
# Epoch 88/100
# 264/264 [==============================] - 0s 656us/step - loss: 7.1173 - mse: 7.1173
# Epoch 89/100
# 264/264 [==============================] - 0s 658us/step - loss: 7.1088 - mse: 7.1088
# Epoch 90/100
# 264/264 [==============================] - 0s 829us/step - loss: 7.2441 - mse: 7.2441
# Epoch 91/100
# 264/264 [==============================] - 0s 2ms/step - loss: 7.2483 - mse: 7.2483
# Epoch 92/100
# 264/264 [==============================] - 0s 2ms/step - loss: 7.2017 - mse: 7.2017
# Epoch 93/100
# 264/264 [==============================] - 0s 1ms/step - loss: 7.0985 - mse: 7.0985
# Epoch 94/100
# 264/264 [==============================] - 0s 712us/step - loss: 7.3099 - mse: 7.3099
# Epoch 95/100
# 264/264 [==============================] - 0s 550us/step - loss: 6.9734 - mse: 6.9734
# Epoch 96/100
# 264/264 [==============================] - 0s 565us/step - loss: 7.3587 - mse: 7.3587
# Epoch 97/100
# 264/264 [==============================] - 0s 529us/step - loss: 7.1477 - mse: 7.1477
# Epoch 98/100
# 264/264 [==============================] - 0s 556us/step - loss: 6.9924 - mse: 6.9924
# Epoch 99/100
# 264/264 [==============================] - 0s 610us/step - loss: 7.0524 - mse: 7.0524
# Epoch 100/100
# 264/264 [==============================] - 0s 591us/step - loss: 7.0512 - mse: 7.0512

# %%
### evaluate the model 
score = model.evaluate(x_test,y_test)
print((model.metrics_names[1]))
# Out:
# 141/141 [==============================] - 0s 445us/step - loss: 11995.8496 - mse: 11995.8496
# mse

# %% [markdown]
# ## Artificial Neural Network Model - Tuning of All Hyperparameters

# %%
import keras

# %% [markdown]
# ###  Tuning of Hyperparameter : Batch size and epochs

# %%
from sklearn.model_selection import GridSearchCV, KFold

from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import adam_v2
# Importing the necessary packages
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import adam_v2
from keras.layers import Dropout

# %%
X = data3.iloc[:,:-1]
Y = data3.iloc[:,-1]

# %%
# Selecting first 500 records
X = X.iloc[0:500,:]
Y = Y.iloc[0:500]

# %%
# Scaling all the features
sc.fit(X)
Y = StandardScaler().fit_transform(Y.values.reshape(len(Y),1))[:,0]
scaled_features=sc.transform(X)
data_head=pd.DataFrame(scaled_features,columns=X.columns)
data_head
# Out:
#          AFDP      GTEP       TIT       TAT       CDP
# 0   -1.759902 -1.532845 -2.140879  0.597669 -1.637742
# 1   -1.760236 -1.516668 -2.132865  0.597669 -1.644533
# 2   -1.789273 -1.503977 -2.124851  0.584370 -1.641623
# 3   -1.792443 -1.500741 -2.108824  0.596646 -1.636771
# 4   -1.763907 -1.507461 -2.100811  0.595623 -1.630950
# ..        ...       ...       ...       ...       ...
# 495  0.427695  0.194256 -0.706435 -0.594154 -0.072722
# 496 -1.244251 -1.463412 -3.919909 -0.777275 -1.760964
# 497 -1.300155 -1.463661 -3.984018 -0.855025 -1.660057
# 498 -1.030481 -1.114010 -3.463131 -0.919476 -1.255462
# 499  0.972718  1.029685  1.144718 -0.334306  0.891710
#
# [500 rows x 5 columns]

# %%
# Splitting data into test data and train data

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train,Y_test = train_test_split(X, Y, test_size=0.3, random_state=1)

# %%
print('Shape of X_train: ', X_train.shape)
print('Shape of X_test: ', X_test.shape)
print('Shape of Y_train: ', Y_train.shape)
print('Shape of Y_test: ', Y_test.shape)
# Out:
# Shape of X_train:  (350, 5)
# Shape of X_test:  (150, 5)
# Shape of Y_train:  (350,)
# Shape of Y_test:  (150,)

# %% [markdown]
# ###  Create model

# %%
def create_model():
    model = Sequential()
    model.add(Dense(12, input_dim = 5, kernel_initializer='he_uniform', activation = 'relu'))
    model.add(Dense(8, kernel_initializer='he_uniform', activation = 'relu'))
    model.add(Dense(1,kernel_initializer='he_uniform', activation ='linear'))
    adam = adam_v2.Adam(learning_rate = 0.01)
    model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse'])
    return model
# create the model
model = KerasClassifier(build_fn = create_model, verbose =0)
# Define the Gread search parameter
batch_size = [20,40]
epochs =[50,100,150]
# make a dictionary of the grid search parameters
para_grid = dict(batch_size = batch_size, epochs = epochs)
# build and fit the GridSearchCV
grid = GridSearchCV(estimator = model, param_grid = para_grid, cv = KFold(), verbose =10, scoring='neg_mean_squared_error')
grid_result = grid.fit(x_test,y_test)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5; 1/6] START batch_size=20, epochs=50....................................
# [CV 1/5; 1/6] END ..................batch_size=20, epochs=50; total time=   3.6s
# [CV 2/5; 1/6] START batch_size=20, epochs=50....................................
# [CV 2/5; 1/6] END ..................batch_size=20, epochs=50; total time=   3.8s
# [CV 3/5; 1/6] START batch_size=20, epochs=50....................................
# [CV 3/5; 1/6] END ..................batch_size=20, epochs=50; total time=   3.7s
# [CV 4/5; 1/6] START batch_size=20, epochs=50....................................
# [CV 4/5; 1/6] END ..................batch_size=20, epochs=50; total time=   4.0s
# [CV 5/5; 1/6] START batch_size=20, epochs=50....................................
# [CV 5/5; 1/6] END ..................batch_size=20, epochs=50; total time=   5.7s
# [CV 1/5; 2/6] START batch_size=20, epochs=100...................................
# [CV 1/5; 2/6] END .................batch_size=20, epochs=100; total time=   9.0s
# [CV 2/5; 2/6] START batch_size=20, epochs=100...................................
# [CV 2/5; 2/6] END .................batch_size=20, epochs=100; total time=   7.9s
# [CV 3/5; 2/6] START batch_size=20, epochs=100...................................
# [CV 3/5; 2/6] END .................batch_size=20, epochs=100; total time=   8.0s
# [CV 4/5; 2/6] START batch_size=20, epochs=100...................................
# [CV 4/5; 2/6] END .................batch_size=20, epochs=100; total time=   8.0s
# [CV 5/5; 2/6] START batch_size=20, epochs=100...................................
# [CV 5/5; 2/6] END .................batch_size=20, epochs=100; total time=   7.9s
# [CV 1/5; 3/6] START batch_size=20, epochs=150...................................
# [CV 1/5; 3/6] END .................batch_size=20, epochs=150; total time=  11.8s
# [CV 2/5; 3/6] START batch_size=20, epochs=150...................................
# [CV 2/5; 3/6] END .................batch_size=20, epochs=150; total time=  12.7s
# [CV 3/5; 3/6] START batch_size=20, epochs=150...................................
# [CV 3/5; 3/6] END .................batch_size=20, epochs=150; total time=  13.8s
# [CV 4/5; 3/6] START batch_size=20, epochs=150...................................
# [CV 4/5; 3/6] END .................batch_size=20, epochs=150; total time=  11.9s
# [CV 5/5; 3/6] START batch_size=20, epochs=150...................................
# [CV 5/5; 3/6] END .................batch_size=20, epochs=150; total time=  11.9s
# [CV 1/5; 4/6] START batch_size=40, epochs=50....................................
# [CV 1/5; 4/6] END ..................batch_size=40, epochs=50; total time=   2.2s
# [CV 2/5; 4/6] START batch_size=40, epochs=50....................................
# [CV 2/5; 4/6] END ..................batch_size=40, epochs=50; total time=   2.2s
# [CV 3/5; 4/6] START batch_size=40, epochs=50....................................
# [CV 3/5; 4/6] END ..................batch_size=40, epochs=50; total time=   2.2s
# [CV 4/5; 4/6] START batch_size=40, epochs=50....................................
# [CV 4/5; 4/6] END ..................batch_size=40, epochs=50; total time=   2.2s
# [CV 5/5; 4/6] START batch_size=40, epochs=50....................................
# [CV 5/5; 4/6] END ..................batch_size=40, epochs=50; total time=   2.2s
# [CV 1/5; 5/6] START batch_size=40, epochs=100...................................
# [CV 1/5; 5/6] END .................batch_size=40, epochs=100; total time=   4.3s
# [CV 2/5; 5/6] START batch_size=40, epochs=100...................................
# [CV 2/5; 5/6] END .................batch_size=40, epochs=100; total time=   4.3s
# [CV 3/5; 5/6] START batch_size=40, epochs=100...................................
# [CV 3/5; 5/6] END .................batch_size=40, epochs=100; total time=   4.3s
# [CV 4/5; 5/6] START batch_size=40, epochs=100...................................
# [CV 4/5; 5/6] END .................batch_size=40, epochs=100; total time=   4.2s
# [CV 5/5; 5/6] START batch_size=40, epochs=100...................................
# [CV 5/5; 5/6] END .................batch_size=40, epochs=100; total time=   5.1s
# [CV 1/5; 6/6] START batch_size=40, epochs=150...................................
# [CV 1/5; 6/6] END .................batch_size=40, epochs=150; total time=   7.6s
# [CV 2/5; 6/6] START batch_size=40, epochs=150...................................
# [CV 2/5; 6/6] END .................batch_size=40, epochs=150; total time=   7.7s
# [CV 3/5; 6/6] START batch_size=40, epochs=150...................................
# [CV 3/5; 6/6] END .................batch_size=40, epochs=150; total time=   7.8s
# [CV 4/5; 6/6] START batch_size=40, epochs=150...................................
# [CV 4/5; 6/6] END .................batch_size=40, epochs=150; total time=   6.7s
# [CV 5/5; 6/6] START batch_size=40, epochs=150...................................
# [CV 5/5; 6/6] END .................batch_size=40, epochs=150; total time=   6.2s

# %%
# summarize the resulting
print('Best : {},using{},'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip (means, stds, params):
    print('{}, {} with: {}'.format(mean,stdev,param))
# Out:
# Best : -1308.0765703006239,using{'batch_size': 20, 'epochs': 50},
# -1308.0765703006239, 49.849293654447685 with: {'batch_size': 20, 'epochs': 50}
# -1308.0765703006239, 49.849293654447685 with: {'batch_size': 20, 'epochs': 100}
# -1308.0765703006239, 49.849293654447685 with: {'batch_size': 20, 'epochs': 150}
# -1308.0765703006239, 49.849293654447685 with: {'batch_size': 40, 'epochs': 50}
# -1308.0765703006239, 49.849293654447685 with: {'batch_size': 40, 'epochs': 100}
# -1308.0765703006239, 49.849293654447685 with: {'batch_size': 40, 'epochs': 150}

# %% [markdown]
# ### Tuning hyperparameter : learning rate and Dropout

# %%
from keras.layers import Dropout

# %%
# Define te maodel
def create_model2(learning_rate,dropout_rate):
    model = Sequential()
    model.add(Dense(8, input_dim = 5, kernel_initializer = 'he_normal', activation ='relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(4, input_dim = 5, kernel_initializer = 'he_normal', activation ='relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))
    adam = adam_v2.Adam(learning_rate = learning_rate)
    model.compile(loss = 'binary_crossentropy', optimizer = adam, metrics =['accuracy'])
    return model

# %%
# create the model
model2 = KerasClassifier(build_fn = create_model2, verbose = 0,batch_size =20, epochs = 50)

# %%
# Define the Grid search parameter
learning_rate = [0.01,0.1]
dropout_rate  = [0.1,0.2]

# %%
# Make a dictionary of the grid dearch parameters
params_grid = dict(learning_rate = learning_rate, dropout_rate = dropout_rate)

# %%
# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model2, param_grid = params_grid, cv = KFold(), verbose = 10)

# %%
grid_result = grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5; 1/4] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 1/5; 1/4] END ......dropout_rate=0.1, learning_rate=0.01; total time=  10.1s
# [CV 2/5; 1/4] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 2/5; 1/4] END ......dropout_rate=0.1, learning_rate=0.01; total time=  11.3s
# [CV 3/5; 1/4] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 3/5; 1/4] END ......dropout_rate=0.1, learning_rate=0.01; total time=  11.0s
# [CV 4/5; 1/4] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 4/5; 1/4] END ......dropout_rate=0.1, learning_rate=0.01; total time=  12.6s
# [CV 5/5; 1/4] START dropout_rate=0.1, learning_rate=0.01........................
# [CV 5/5; 1/4] END ......dropout_rate=0.1, learning_rate=0.01; total time=  12.7s
# [CV 1/5; 2/4] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 1/5; 2/4] END .......dropout_rate=0.1, learning_rate=0.1; total time=  13.4s
# [CV 2/5; 2/4] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 2/5; 2/4] END .......dropout_rate=0.1, learning_rate=0.1; total time=  11.7s
# [CV 3/5; 2/4] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 3/5; 2/4] END .......dropout_rate=0.1, learning_rate=0.1; total time=  12.2s
# [CV 4/5; 2/4] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 4/5; 2/4] END .......dropout_rate=0.1, learning_rate=0.1; total time=  11.9s
# [CV 5/5; 2/4] START dropout_rate=0.1, learning_rate=0.1.........................
# [CV 5/5; 2/4] END .......dropout_rate=0.1, learning_rate=0.1; total time=  12.8s
# [CV 1/5; 3/4] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 1/5; 3/4] END ......dropout_rate=0.2, learning_rate=0.01; total time=  11.9s
# [CV 2/5; 3/4] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 2/5; 3/4] END ......dropout_rate=0.2, learning_rate=0.01; total time=  11.8s
# [CV 3/5; 3/4] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 3/5; 3/4] END ......dropout_rate=0.2, learning_rate=0.01; total time=  11.8s
# [CV 4/5; 3/4] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 4/5; 3/4] END ......dropout_rate=0.2, learning_rate=0.01; total time=  13.7s
# [CV 5/5; 3/4] START dropout_rate=0.2, learning_rate=0.01........................
# [CV 5/5; 3/4] END ......dropout_rate=0.2, learning_rate=0.01; total time=  12.3s
# [CV 1/5; 4/4] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 1/5; 4/4] END .......dropout_rate=0.2, learning_rate=0.1; total time=  14.0s
# [CV 2/5; 4/4] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 2/5; 4/4] END .......dropout_rate=0.2, learning_rate=0.1; total time=  13.4s
# [CV 3/5; 4/4] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 3/5; 4/4] END .......dropout_rate=0.2, learning_rate=0.1; total time=  11.8s
# [CV 4/5; 4/4] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 4/5; 4/4] END .......dropout_rate=0.2, learning_rate=0.1; total time=  12.7s
# [CV 5/5; 4/4] START dropout_rate=0.2, learning_rate=0.1.........................
# [CV 5/5; 4/4] END .......dropout_rate=0.2, learning_rate=0.1; total time=  12.9s

# %%
# Summarise the results
print('Best: {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip (means, stds, params):
    print('{}, {} with: {}'.format(mean, stdev, param))
# Out:
# Best: 9.501187596470118e-05, using {'dropout_rate': 0.1, 'learning_rate': 0.01}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'dropout_rate': 0.1, 'learning_rate': 0.01}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'dropout_rate': 0.1, 'learning_rate': 0.1}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'dropout_rate': 0.2, 'learning_rate': 0.01}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'dropout_rate': 0.2, 'learning_rate': 0.1}

# %% [markdown]
# ###  Tunning of hyperparameter : Activation and Kernel Initializer

# %%
# Define the model
def create_model3 (activation_function,init):
    model = Sequential()
    model.add(Dense(8,input_dim = 5, kernel_initializer =init,activation = activation_function))
    model.add(Dropout(0.1))            
    model.add(Dense(4, input_dim = 5, kernel_initializer =init, activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(1, activation = 'sigmoid'))
    
    adam = adam_v2.Adam(learning_rate =0.001)
    model.compile(loss= 'binary_crossentropy', optimizer = adam , metrics = ['accuracy'])
    return model

# %%
#  create the model
model3 =KerasClassifier(build_fn = create_model3, verbose =0, batch_size = 20, epochs =50)

# %%
# Define the grid search parameters
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']

# %%
# make a dictionary of the grid search parameter

param_gridss = dict(activation_function = activation_function, init= init)

# %%
# build and fit the gridsearchcv 

grids = GridSearchCV(estimator =model3, param_grid = param_gridss , cv = KFold(), verbose = 10)
grids_results = grids.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 1/5; 1/12] END activation_function=softmax, init=uniform; total time=  14.0s
# [CV 2/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 2/5; 1/12] END activation_function=softmax, init=uniform; total time=  12.5s
# [CV 3/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 3/5; 1/12] END activation_function=softmax, init=uniform; total time=  13.6s
# [CV 4/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 4/5; 1/12] END activation_function=softmax, init=uniform; total time=  13.2s
# [CV 5/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 5/5; 1/12] END activation_function=softmax, init=uniform; total time=  13.0s
# [CV 1/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 1/5; 2/12] END .activation_function=softmax, init=normal; total time=  13.8s
# [CV 2/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 2/5; 2/12] END .activation_function=softmax, init=normal; total time=  12.5s
# [CV 3/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 3/5; 2/12] END .activation_function=softmax, init=normal; total time=  12.7s
# [CV 4/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 4/5; 2/12] END .activation_function=softmax, init=normal; total time=  13.5s
# [CV 5/5; 2/12] START activation_function=softmax, init=normal...................
# [CV 5/5; 2/12] END .activation_function=softmax, init=normal; total time=  13.1s
# [CV 1/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 1/5; 3/12] END ...activation_function=softmax, init=zero; total time=  13.1s
# [CV 2/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 2/5; 3/12] END ...activation_function=softmax, init=zero; total time=  14.1s
# [CV 3/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 3/5; 3/12] END ...activation_function=softmax, init=zero; total time=  13.0s
# [CV 4/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 4/5; 3/12] END ...activation_function=softmax, init=zero; total time=  14.5s
# [CV 5/5; 3/12] START activation_function=softmax, init=zero.....................
# [CV 5/5; 3/12] END ...activation_function=softmax, init=zero; total time=  13.0s
# [CV 1/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 1/5; 4/12] END ...activation_function=relu, init=uniform; total time=  13.8s
# [CV 2/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 2/5; 4/12] END ...activation_function=relu, init=uniform; total time=  11.8s
# [CV 3/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 3/5; 4/12] END ...activation_function=relu, init=uniform; total time=  12.8s
# [CV 4/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 4/5; 4/12] END ...activation_function=relu, init=uniform; total time=  12.8s
# [CV 5/5; 4/12] START activation_function=relu, init=uniform.....................
# [CV 5/5; 4/12] END ...activation_function=relu, init=uniform; total time=  12.8s
# [CV 1/5; 5/12] START activation_function=relu, init=normal......................
# [CV 1/5; 5/12] END ....activation_function=relu, init=normal; total time=  12.8s
# [CV 2/5; 5/12] START activation_function=relu, init=normal......................
# [CV 2/5; 5/12] END ....activation_function=relu, init=normal; total time=  13.0s
# [CV 3/5; 5/12] START activation_function=relu, init=normal......................
# [CV 3/5; 5/12] END ....activation_function=relu, init=normal; total time=  12.5s
# [CV 4/5; 5/12] START activation_function=relu, init=normal......................
# [CV 4/5; 5/12] END ....activation_function=relu, init=normal; total time=  12.8s
# [CV 5/5; 5/12] START activation_function=relu, init=normal......................
# [CV 5/5; 5/12] END ....activation_function=relu, init=normal; total time=  12.9s
# [CV 1/5; 6/12] START activation_function=relu, init=zero........................
# [CV 1/5; 6/12] END ......activation_function=relu, init=zero; total time=  14.4s
# [CV 2/5; 6/12] START activation_function=relu, init=zero........................
# [CV 2/5; 6/12] END ......activation_function=relu, init=zero; total time=  12.9s
# [CV 3/5; 6/12] START activation_function=relu, init=zero........................
# [CV 3/5; 6/12] END ......activation_function=relu, init=zero; total time=  12.8s
# [CV 4/5; 6/12] START activation_function=relu, init=zero........................
# [CV 4/5; 6/12] END ......activation_function=relu, init=zero; total time=  11.9s
# [CV 5/5; 6/12] START activation_function=relu, init=zero........................
# [CV 5/5; 6/12] END ......activation_function=relu, init=zero; total time=  13.9s
# [CV 1/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 1/5; 7/12] END ...activation_function=tanh, init=uniform; total time=  12.9s
# [CV 2/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 2/5; 7/12] END ...activation_function=tanh, init=uniform; total time=  13.0s
# [CV 3/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 3/5; 7/12] END ...activation_function=tanh, init=uniform; total time=  13.6s
# [CV 4/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 4/5; 7/12] END ...activation_function=tanh, init=uniform; total time=  12.2s
# [CV 5/5; 7/12] START activation_function=tanh, init=uniform.....................
# [CV 5/5; 7/12] END ...activation_function=tanh, init=uniform; total time=  13.3s
# [CV 1/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 1/5; 8/12] END ....activation_function=tanh, init=normal; total time=  12.1s
# [CV 2/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 2/5; 8/12] END ....activation_function=tanh, init=normal; total time=  13.5s
# [CV 3/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 3/5; 8/12] END ....activation_function=tanh, init=normal; total time=  13.0s
# [CV 4/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 4/5; 8/12] END ....activation_function=tanh, init=normal; total time=  14.8s
# [CV 5/5; 8/12] START activation_function=tanh, init=normal......................
# [CV 5/5; 8/12] END ....activation_function=tanh, init=normal; total time=  14.6s
# [CV 1/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 1/5; 9/12] END ......activation_function=tanh, init=zero; total time=  13.7s
# [CV 2/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 2/5; 9/12] END ......activation_function=tanh, init=zero; total time=  17.3s
# [CV 3/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 3/5; 9/12] END ......activation_function=tanh, init=zero; total time=  16.7s
# [CV 4/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 4/5; 9/12] END ......activation_function=tanh, init=zero; total time=  13.2s
# [CV 5/5; 9/12] START activation_function=tanh, init=zero........................
# [CV 5/5; 9/12] END ......activation_function=tanh, init=zero; total time=  12.8s
# [CV 1/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 1/5; 10/12] END activation_function=linear, init=uniform; total time=  13.3s
# [CV 2/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 2/5; 10/12] END activation_function=linear, init=uniform; total time=  13.4s
# [CV 3/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 3/5; 10/12] END activation_function=linear, init=uniform; total time=  12.8s
# [CV 4/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 4/5; 10/12] END activation_function=linear, init=uniform; total time=  13.3s
# [CV 5/5; 10/12] START activation_function=linear, init=uniform..................
# [CV 5/5; 10/12] END activation_function=linear, init=uniform; total time=  13.1s
# [CV 1/5; 11/12] START activation_function=linear, init=normal...................
# [CV 1/5; 11/12] END .activation_function=linear, init=normal; total time=  12.7s
# [CV 2/5; 11/12] START activation_function=linear, init=normal...................
# [CV 2/5; 11/12] END .activation_function=linear, init=normal; total time=  13.4s
# [CV 3/5; 11/12] START activation_function=linear, init=normal...................
# [CV 3/5; 11/12] END .activation_function=linear, init=normal; total time=  13.7s
# [CV 4/5; 11/12] START activation_function=linear, init=normal...................
# [CV 4/5; 11/12] END .activation_function=linear, init=normal; total time=  14.3s
# [CV 5/5; 11/12] START activation_function=linear, init=normal...................
# [CV 5/5; 11/12] END .activation_function=linear, init=normal; total time=  11.8s
# [CV 1/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 1/5; 12/12] END ...activation_function=linear, init=zero; total time=  13.0s
# [CV 2/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 2/5; 12/12] END ...activation_function=linear, init=zero; total time=  12.3s
# [CV 3/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 3/5; 12/12] END ...activation_function=linear, init=zero; total time=  12.8s
# [CV 4/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 4/5; 12/12] END ...activation_function=linear, init=zero; total time=  13.5s
# [CV 5/5; 12/12] START activation_function=linear, init=zero.....................
# [CV 5/5; 12/12] END ...activation_function=linear, init=zero; total time=  13.0s

# %%
# Summarise the results
print('Best: {}, using {}'.format(grids_results.best_score_,grids_results.best_params_))
means = grids_results.cv_results_['mean_test_score']
stds = grids_results.cv_results_['std_test_score']
params = grids_results.cv_results_['params']
for mean, stdev, param in zip (means, stds, params):
    print('{}, {} with: {}'.format(mean, stdev, param))
# Out:
# Best: 9.501187596470118e-05, using {'activation_function': 'softmax', 'init': 'uniform'}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'activation_function': 'softmax', 'init': 'uniform'}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'activation_function': 'softmax', 'init': 'normal'}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'activation_function': 'softmax', 'init': 'zero'}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'activation_function': 'relu', 'init': 'uniform'}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'activation_function': 'relu', 'init': 'normal'}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'activation_function': 'relu', 'init': 'zero'}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'activation_function': 'tanh', 'init': 'uniform'}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'activation_function': 'tanh', 'init': 'normal'}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'activation_function': 'tanh', 'init': 'zero'}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'activation_function': 'linear', 'init': 'uniform'}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'activation_function': 'linear', 'init': 'normal'}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'activation_function': 'linear', 'init': 'zero'}

# %% [markdown]
# ###  Tuning of hyperparameter : Number of neurons in activation number

# %%
# Define the model
def create_model4(neuron1,neuron2):
    model.add(Dense(neuron1, input_dim = 5, kernel_initialize = 'uniform', activation = 'softmax'))
    model.add(Dropout(0.1))
    model.add(Dense(nueron2, input_dim = neuron1, kernel_initializer = 'uniform', activation = 'softmax'))
    model.add(Dense(1, activation = 'sigmoid'))
   
    adam = adam_v2.Adam(learning_rate = 0.01)
    model.compile(loss ='binary_crossentropy', optimizer = adam, metrics = 'accuracy')
    return model

# Create the model
model4 = KerasClassifier(build_fn = create_model4, verbose= 0, batch_size = 40, epochs = 10)

# Define the grid search parameter
neuron1 = [4,8,16]
neuron2 = [2,6,8]

# make a dictionary of the grid search parameter
param_grids = dict(neuron1 = neuron1,neuron2 = neuron2)


# Build and fit the GridSearchCV
grid1 = GridSearchCV(estimator = model, param_grid= param_grids,cv =KFold(), verbose = 10)
grid_result1 = grid1.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 1/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   1.4s
# [CV 2/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 2/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   1.6s
# [CV 3/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 3/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   1.7s
# [CV 4/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 4/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   1.7s
# [CV 5/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 5/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   1.4s
# [CV 1/5; 2/9] START neuron1=4, neuron2=6........................................
# [CV 1/5; 2/9] END ......................neuron1=4, neuron2=6; total time=   1.4s
# [CV 2/5; 2/9] START neuron1=4, neuron2=6........................................
# [CV 2/5; 2/9] END ......................neuron1=4, neuron2=6; total time=   1.4s
# [CV 3/5; 2/9] START neuron1=4, neuron2=6........................................
# [CV 3/5; 2/9] END ......................neuron1=4, neuron2=6; total time=   1.6s
# [CV 4/5; 2/9] START neuron1=4, neuron2=6........................................
# [CV 4/5; 2/9] END ......................neuron1=4, neuron2=6; total time=   1.4s
# [CV 5/5; 2/9] START neuron1=4, neuron2=6........................................
# [CV 5/5; 2/9] END ......................neuron1=4, neuron2=6; total time=   1.4s
# [CV 1/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 1/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   1.8s
# [CV 2/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 2/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   1.5s
# [CV 3/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 3/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   2.0s
# [CV 4/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 4/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   1.6s
# [CV 5/5; 3/9] START neuron1=4, neuron2=8........................................
# [CV 5/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   1.4s
# [CV 1/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 1/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   1.8s
# [CV 2/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 2/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   1.4s
# [CV 3/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 3/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   1.5s
# [CV 4/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 4/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   1.6s
# [CV 5/5; 4/9] START neuron1=8, neuron2=2........................................
# [CV 5/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   1.4s
# [CV 1/5; 5/9] START neuron1=8, neuron2=6........................................
# [CV 1/5; 5/9] END ......................neuron1=8, neuron2=6; total time=   1.4s
# [CV 2/5; 5/9] START neuron1=8, neuron2=6........................................
# [CV 2/5; 5/9] END ......................neuron1=8, neuron2=6; total time=   1.4s
# [CV 3/5; 5/9] START neuron1=8, neuron2=6........................................
# [CV 3/5; 5/9] END ......................neuron1=8, neuron2=6; total time=   1.4s
# [CV 4/5; 5/9] START neuron1=8, neuron2=6........................................
# [CV 4/5; 5/9] END ......................neuron1=8, neuron2=6; total time=   1.4s
# [CV 5/5; 5/9] START neuron1=8, neuron2=6........................................
# [CV 5/5; 5/9] END ......................neuron1=8, neuron2=6; total time=   1.4s
# [CV 1/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 1/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   1.6s
# [CV 2/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 2/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   1.4s
# [CV 3/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 3/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   1.4s
# [CV 4/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 4/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   1.4s
# [CV 5/5; 6/9] START neuron1=8, neuron2=8........................................
# [CV 5/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   1.4s
# [CV 1/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 1/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   1.4s
# [CV 2/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 2/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   1.4s
# [CV 3/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 3/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   1.5s
# [CV 4/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 4/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   1.4s
# [CV 5/5; 7/9] START neuron1=16, neuron2=2.......................................
# [CV 5/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   1.9s
# [CV 1/5; 8/9] START neuron1=16, neuron2=6.......................................
# [CV 1/5; 8/9] END .....................neuron1=16, neuron2=6; total time=   1.6s
# [CV 2/5; 8/9] START neuron1=16, neuron2=6.......................................
# [CV 2/5; 8/9] END .....................neuron1=16, neuron2=6; total time=   1.8s
# [CV 3/5; 8/9] START neuron1=16, neuron2=6.......................................
# [CV 3/5; 8/9] END .....................neuron1=16, neuron2=6; total time=   1.7s
# [CV 4/5; 8/9] START neuron1=16, neuron2=6.......................................
# [CV 4/5; 8/9] END .....................neuron1=16, neuron2=6; total time=   1.7s
# [CV 5/5; 8/9] START neuron1=16, neuron2=6.......................................
# [CV 5/5; 8/9] END .....................neuron1=16, neuron2=6; total time=   1.7s
# [CV 1/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 1/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   1.6s
# [CV 2/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 2/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   1.7s
# [CV 3/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 3/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   1.8s
# [CV 4/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 4/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   1.7s
# [CV 5/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 5/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   1.6s

# %%
# Summarise the results
print('Best: {}, using {}'.format(grid_result1.best_score_,grid_result1.best_params_))
means = grid_result1.cv_results_['mean_test_score']
stds = grid_result1.cv_results_['std_test_score']
params = grid_result1.cv_results_['params']
for mean, stdev, param in zip (means, stds, params):
    print('{}, {} with: {}'.format(mean, stdev, param))
# Out:
# Best: 9.501187596470118e-05, using {'neuron1': 4, 'neuron2': 2}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'neuron1': 4, 'neuron2': 2}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'neuron1': 4, 'neuron2': 6}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'neuron1': 4, 'neuron2': 8}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'neuron1': 8, 'neuron2': 2}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'neuron1': 8, 'neuron2': 6}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'neuron1': 8, 'neuron2': 8}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'neuron1': 16, 'neuron2': 2}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'neuron1': 16, 'neuron2': 6}
# 9.501187596470118e-05, 0.00019002375192940236 with: {'neuron1': 16, 'neuron2': 8}

# %%
def create_model(learning_rate,dropout_rate,activation_function,init,neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 5,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'linear'))
    
    adam=adam_v2.Adam(learning_rate = learning_rate)
    model.compile(loss = 'mean_squared_error',optimizer = adam,metrics = ['mse'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0)

# Define the grid search parameters

batch_size = [20,40]
epochs = [50,100]
learning_rate = [0.01,0.1]
dropout_rate = [0.1,0.2]
activation_function = ['relu','linear']
init = ['uniform','normal']
neuron1 = [4,8]
neuron2 = [2,4]

# Make a dictionary of the grid search parameters

param_grids = dict(batch_size = batch_size,epochs = epochs,learning_rate = learning_rate,dropout_rate = dropout_rate,
                   activation_function = activation_function,init = init,neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10, scoring='neg_mean_squared_error')
grid_result = grid.fit(X_train, Y_train)

# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
# Out:
# Fitting 5 folds for each of 256 candidates, totalling 1280 fits
# [CV 1/5; 1/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 1/5; 1/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2; total time=   0.5s
# [CV 2/5; 1/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 2/5; 1/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2; total time=   0.5s
# [CV 3/5; 1/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 3/5; 1/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2; total time=   0.5s
# [CV 4/5; 1/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# WARNING:tensorflow:5 out of the last 39 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000184ABF8F040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [CV 4/5; 1/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2; total time=   0.8s
# [CV 5/5; 1/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000184A41DFB80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [CV 5/5; 1/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2; total time=   1.2s
# [CV 1/5; 2/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 1/5; 2/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4; total time=   0.5s
# [CV 2/5; 2/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 2/5; 2/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4; total time=   0.5s
# [CV 3/5; 2/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 3/5; 2/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4; total time=   0.5s
# [CV 4/5; 2/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 4/5; 2/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4; total time=   0.5s
# [CV 5/5; 2/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 5/5; 2/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4; total time=   1.3s
# [CV 1/5; 3/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 1/5; 3/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2; total time=   0.8s
# [CV 2/5; 3/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 2/5; 3/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2; total time=   0.6s
# [CV 3/5; 3/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 3/5; 3/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2; total time=   0.9s
# [CV 4/5; 3/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 4/5; 3/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2; total time=   1.1s
# [CV 5/5; 3/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 5/5; 3/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2; total time=   0.5s
# [CV 1/5; 4/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 1/5; 4/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4; total time=   0.5s
# [CV 2/5; 4/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 2/5; 4/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4; total time=   1.4s
# [CV 3/5; 4/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 3/5; 4/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4; total time=   0.5s
# [CV 4/5; 4/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 4/5; 4/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4; total time=   0.5s
# [CV 5/5; 4/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 5/5; 4/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4; total time=   1.3s
# [CV 1/5; 5/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 1/5; 5/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2; total time=   0.8s
# [CV 2/5; 5/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 2/5; 5/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2; total time=   0.6s
# [CV 3/5; 5/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 3/5; 5/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2; total time=   0.8s
# [CV 4/5; 5/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 4/5; 5/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2; total time=   0.6s
# [CV 5/5; 5/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 5/5; 5/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2; total time=   1.2s
# [CV 1/5; 6/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 1/5; 6/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4; total time=   0.8s
# [CV 2/5; 6/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 2/5; 6/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4; total time=   0.5s
# [CV 3/5; 6/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 3/5; 6/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4; total time=   0.8s
# [CV 4/5; 6/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 4/5; 6/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4; total time=   1.2s
# [CV 5/5; 6/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 5/5; 6/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4; total time=   0.5s
# [CV 1/5; 7/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 1/5; 7/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2; total time=   0.5s
# [CV 2/5; 7/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 2/5; 7/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2; total time=   0.5s
# [CV 3/5; 7/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 3/5; 7/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2; total time=   0.5s
# [CV 4/5; 7/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 4/5; 7/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2; total time=   0.6s
# [CV 5/5; 7/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 5/5; 7/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2; total time=   1.3s
# [CV 1/5; 8/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 1/5; 8/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4; total time=   0.7s
# [CV 2/5; 8/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 2/5; 8/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4; total time=   0.6s
# [CV 3/5; 8/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 3/5; 8/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4; total time=   1.4s
# [CV 4/5; 8/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 4/5; 8/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4; total time=   0.5s
# [CV 5/5; 8/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 5/5; 8/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4; total time=   0.5s
# [CV 1/5; 9/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 1/5; 9/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=2; total time=   1.1s
# [CV 2/5; 9/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 2/5; 9/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=2; total time=   0.8s
# [CV 3/5; 9/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 3/5; 9/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=2; total time=   0.5s
# [CV 4/5; 9/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 4/5; 9/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=2; total time=   0.5s
# [CV 5/5; 9/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 5/5; 9/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=2; total time=   1.3s
# [CV 1/5; 10/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 1/5; 10/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=4; total time=   0.6s
# [CV 2/5; 10/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 2/5; 10/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=4; total time=   0.5s
# [CV 3/5; 10/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 3/5; 10/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=4; total time=   1.3s
# [CV 4/5; 10/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 4/5; 10/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=4; total time=   0.8s
# [CV 5/5; 10/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 5/5; 10/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=4, neuron2=4; total time=   0.5s
# [CV 1/5; 11/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 1/5; 11/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=2; total time=   0.6s
# [CV 2/5; 11/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 2/5; 11/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=2; total time=   1.3s
# [CV 3/5; 11/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 3/5; 11/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=2; total time=   0.5s
# [CV 4/5; 11/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 4/5; 11/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=2; total time=   0.5s
# [CV 5/5; 11/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 5/5; 11/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=2; total time=   1.1s
# [CV 1/5; 12/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 1/5; 12/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=4; total time=   0.9s
# [CV 2/5; 12/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 2/5; 12/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=4; total time=   0.5s
# [CV 3/5; 12/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 3/5; 12/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=4; total time=   0.6s
# [CV 4/5; 12/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 4/5; 12/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=4; total time=   1.4s
# [CV 5/5; 12/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 5/5; 12/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.01, neuron1=8, neuron2=4; total time=   0.6s
# [CV 1/5; 13/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 1/5; 13/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=2; total time=   1.1s
# [CV 2/5; 13/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 2/5; 13/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=2; total time=   1.1s
# [CV 3/5; 13/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 3/5; 13/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=2; total time=   0.8s
# [CV 4/5; 13/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 4/5; 13/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=2; total time=   1.4s
# [CV 5/5; 13/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 5/5; 13/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=2; total time=   1.0s
# [CV 1/5; 14/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 1/5; 14/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=4; total time=   1.2s
# [CV 2/5; 14/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 2/5; 14/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=4; total time=   1.4s
# [CV 3/5; 14/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 3/5; 14/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=4; total time=   0.5s
# [CV 4/5; 14/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 4/5; 14/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=4; total time=   0.9s
# [CV 5/5; 14/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 5/5; 14/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=4, neuron2=4; total time=   1.0s
# [CV 1/5; 15/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 1/5; 15/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=2; total time=   0.5s
# [CV 2/5; 15/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 2/5; 15/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=2; total time=   0.5s
# [CV 3/5; 15/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 3/5; 15/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=2; total time=   1.3s
# [CV 4/5; 15/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 4/5; 15/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=2; total time=   0.8s
# [CV 5/5; 15/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 5/5; 15/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=2; total time=   0.5s
# [CV 1/5; 16/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 1/5; 16/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=4; total time=   1.3s
# [CV 2/5; 16/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 2/5; 16/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=4; total time=   0.7s
# [CV 3/5; 16/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 3/5; 16/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=4; total time=   0.5s
# [CV 4/5; 16/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 4/5; 16/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=4; total time=   0.9s
# [CV 5/5; 16/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 5/5; 16/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=50, init=normal, learning_rate=0.1, neuron1=8, neuron2=4; total time=   1.0s
# [CV 1/5; 17/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 1/5; 17/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2; total time=   0.8s
# [CV 2/5; 17/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 2/5; 17/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2; total time=   1.5s
# [CV 3/5; 17/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 3/5; 17/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2; total time=   1.0s
# [CV 4/5; 17/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 4/5; 17/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2; total time=   1.2s
# [CV 5/5; 17/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 5/5; 17/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2; total time=   1.5s
# [CV 1/5; 18/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 1/5; 18/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4; total time=   1.0s
# [CV 2/5; 18/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 2/5; 18/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4; total time=   0.8s
# [CV 3/5; 18/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 3/5; 18/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4; total time=   1.4s
# [CV 4/5; 18/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 4/5; 18/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4; total time=   1.2s
# [CV 5/5; 18/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 5/5; 18/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4; total time=   0.9s
# [CV 1/5; 19/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 1/5; 19/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2; total time=   1.7s
# [CV 2/5; 19/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 2/5; 19/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2; total time=   0.8s
# [CV 3/5; 19/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 3/5; 19/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2; total time=   1.7s
# [CV 4/5; 19/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 4/5; 19/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2; total time=   0.8s
# [CV 5/5; 19/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 5/5; 19/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2; total time=   1.6s
# [CV 1/5; 20/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 1/5; 20/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4; total time=   1.4s
# [CV 2/5; 20/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 2/5; 20/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4; total time=   1.8s
# [CV 3/5; 20/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 3/5; 20/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4; total time=   0.8s
# [CV 4/5; 20/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 4/5; 20/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4; total time=   1.0s
# [CV 5/5; 20/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 5/5; 20/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4; total time=   0.8s
# [CV 1/5; 21/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 1/5; 21/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2; total time=   1.7s
# [CV 2/5; 21/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 2/5; 21/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2; total time=   0.8s
# [CV 3/5; 21/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 3/5; 21/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2; total time=   1.7s
# [CV 4/5; 21/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 4/5; 21/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2; total time=   0.9s
# [CV 5/5; 21/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 5/5; 21/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2; total time=   0.8s
# [CV 1/5; 22/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 1/5; 22/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4; total time=   0.8s
# [CV 2/5; 22/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 2/5; 22/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4; total time=   1.6s
# [CV 3/5; 22/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 3/5; 22/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4; total time=   0.9s
# [CV 4/5; 22/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 4/5; 22/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4; total time=   0.9s
# [CV 5/5; 22/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 5/5; 22/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4; total time=   1.6s
# [CV 1/5; 23/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 1/5; 23/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2; total time=   0.8s
# [CV 2/5; 23/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 2/5; 23/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2; total time=   2.0s
# [CV 3/5; 23/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 3/5; 23/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2; total time=   0.8s
# [CV 4/5; 23/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 4/5; 23/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2; total time=   1.8s
# [CV 5/5; 23/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 5/5; 23/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2; total time=   1.0s
# [CV 1/5; 24/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 1/5; 24/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4; total time=   1.6s
# [CV 2/5; 24/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 2/5; 24/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4; total time=   0.9s
# [CV 3/5; 24/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 3/5; 24/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4; total time=   1.2s
# [CV 4/5; 24/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 4/5; 24/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4; total time=   1.4s
# [CV 5/5; 24/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 5/5; 24/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4; total time=   0.8s
# [CV 1/5; 25/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 1/5; 25/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2; total time=   1.7s
# [CV 2/5; 25/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 2/5; 25/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2; total time=   0.8s
# [CV 3/5; 25/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 3/5; 25/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2; total time=   1.4s
# [CV 4/5; 25/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 4/5; 25/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2; total time=   1.3s
# [CV 5/5; 25/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 5/5; 25/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2; total time=   0.8s
# [CV 1/5; 26/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 1/5; 26/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4; total time=   0.8s
# [CV 2/5; 26/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 2/5; 26/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4; total time=   1.8s
# [CV 3/5; 26/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 3/5; 26/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4; total time=   0.8s
# [CV 4/5; 26/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 4/5; 26/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4; total time=   1.5s
# [CV 5/5; 26/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 5/5; 26/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4; total time=   1.4s
# [CV 1/5; 27/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 1/5; 27/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2; total time=   1.6s
# [CV 2/5; 27/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 2/5; 27/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2; total time=   1.2s
# [CV 3/5; 27/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 3/5; 27/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2; total time=   2.1s
# [CV 4/5; 27/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 4/5; 27/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2; total time=   1.1s
# [CV 5/5; 27/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 5/5; 27/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2; total time=   1.9s
# [CV 1/5; 28/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 1/5; 28/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4; total time=   1.0s
# [CV 2/5; 28/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 2/5; 28/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4; total time=   1.9s
# [CV 3/5; 28/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 3/5; 28/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4; total time=   0.8s
# [CV 4/5; 28/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 4/5; 28/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4; total time=   2.0s
# [CV 5/5; 28/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 5/5; 28/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4; total time=   0.8s
# [CV 1/5; 29/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 1/5; 29/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2; total time=   1.4s
# [CV 2/5; 29/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 2/5; 29/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2; total time=   1.1s
# [CV 3/5; 29/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 3/5; 29/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2; total time=   0.8s
# [CV 4/5; 29/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 4/5; 29/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2; total time=   1.7s
# [CV 5/5; 29/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 5/5; 29/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2; total time=   0.8s
# [CV 1/5; 30/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 1/5; 30/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4; total time=   1.8s
# [CV 2/5; 30/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 2/5; 30/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4; total time=   0.8s
# [CV 3/5; 30/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 3/5; 30/256] END activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4; total time=   1.2s
# [CV 4/5; 30/256] START activation_function=relu, batch_size=20, dropout_rate=0.1, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# ...
# [CV 1/5; 247/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2; total time=   1.0s
# [CV 2/5; 247/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 2/5; 247/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2; total time=   0.5s
# [CV 3/5; 247/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 3/5; 247/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2; total time=   0.5s
# [CV 4/5; 247/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 4/5; 247/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2; total time=   1.4s
# [CV 5/5; 247/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 5/5; 247/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2; total time=   0.6s
# [CV 1/5; 248/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 1/5; 248/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4; total time=   0.5s
# [CV 2/5; 248/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 2/5; 248/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4; total time=   1.5s
# [CV 3/5; 248/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 3/5; 248/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4; total time=   0.7s
# [CV 4/5; 248/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 4/5; 248/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4; total time=   0.5s
# [CV 5/5; 248/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 5/5; 248/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4; total time=   0.9s
# [CV 1/5; 249/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 1/5; 249/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2; total time=   1.0s
# [CV 2/5; 249/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 2/5; 249/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2; total time=   0.5s
# [CV 3/5; 249/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 3/5; 249/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2; total time=   0.5s
# [CV 4/5; 249/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 4/5; 249/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2; total time=   1.4s
# [CV 5/5; 249/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2
# [CV 5/5; 249/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=2; total time=   0.6s
# [CV 1/5; 250/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 1/5; 250/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4; total time=   0.5s
# [CV 2/5; 250/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 2/5; 250/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4; total time=   1.1s
# [CV 3/5; 250/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 3/5; 250/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4; total time=   1.0s
# [CV 4/5; 250/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 4/5; 250/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4; total time=   0.5s
# [CV 5/5; 250/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4
# [CV 5/5; 250/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=4, neuron2=4; total time=   0.7s
# [CV 1/5; 251/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 1/5; 251/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2; total time=   0.5s
# [CV 2/5; 251/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 2/5; 251/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2; total time=   0.5s
# [CV 3/5; 251/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 3/5; 251/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2; total time=   1.5s
# [CV 4/5; 251/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 4/5; 251/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2; total time=   0.6s
# [CV 5/5; 251/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2
# [CV 5/5; 251/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=2; total time=   0.5s
# [CV 1/5; 252/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 1/5; 252/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4; total time=   1.1s
# [CV 2/5; 252/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 2/5; 252/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4; total time=   0.8s
# [CV 3/5; 252/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 3/5; 252/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4; total time=   0.5s
# [CV 4/5; 252/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 4/5; 252/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4; total time=   0.6s
# [CV 5/5; 252/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4
# [CV 5/5; 252/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.01, neuron1=8, neuron2=4; total time=   1.4s
# [CV 1/5; 253/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 1/5; 253/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2; total time=   0.6s
# [CV 2/5; 253/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 2/5; 253/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2; total time=   0.5s
# [CV 3/5; 253/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 3/5; 253/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2; total time=   0.7s
# [CV 4/5; 253/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 4/5; 253/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2; total time=   0.5s
# [CV 5/5; 253/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2
# [CV 5/5; 253/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=2; total time=   1.4s
# [CV 1/5; 254/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 1/5; 254/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4; total time=   0.7s
# [CV 2/5; 254/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 2/5; 254/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4; total time=   0.5s
# [CV 3/5; 254/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 3/5; 254/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4; total time=   1.1s
# [CV 4/5; 254/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 4/5; 254/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4; total time=   1.0s
# [CV 5/5; 254/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4
# [CV 5/5; 254/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=4, neuron2=4; total time=   0.7s
# [CV 1/5; 255/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 1/5; 255/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=2; total time=   0.7s
# [CV 2/5; 255/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 2/5; 255/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=2; total time=   0.6s
# [CV 3/5; 255/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 3/5; 255/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=2; total time=   1.3s
# [CV 4/5; 255/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 4/5; 255/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=2; total time=   0.7s
# [CV 5/5; 255/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=2
# [CV 5/5; 255/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=2; total time=   0.5s
# [CV 1/5; 256/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 1/5; 256/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=4; total time=   0.8s
# [CV 2/5; 256/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 2/5; 256/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=4; total time=   0.5s
# [CV 3/5; 256/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 3/5; 256/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=4; total time=   1.2s
# [CV 4/5; 256/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 4/5; 256/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=4; total time=   0.9s
# [CV 5/5; 256/256] START activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=4
# [CV 5/5; 256/256] END activation_function=linear, batch_size=40, dropout_rate=0.2, epochs=100, init=normal, learning_rate=0.1, neuron1=8, neuron2=4; total time=   0.5s
# Best : -4.989548995284916, using {'activation_function': 'relu', 'batch_size': 20, 'dropout_rate': 0.1, 'epochs': 50, 'init': 'uniform', 'learning_rate': 0.01, 'neuron1': 4, 'neuron2': 2}

# %% [markdown]
# ###  final model

# %%
# create model
final_model = Sequential()
final_model.add(Dense(4, input_dim=5, kernel_initializer ='uniform', activation='softmax'))
final_model.add(Dropout(0.1))
final_model.add(Dense(2, kernel_initializer='uniform', activation='softmax'))
final_model.add(Dropout(0.1))
final_model.add(Dense(1, kernel_initializer='uniform', activation='linear'))

adam=adam_v2.Adam(learning_rate = 0.01)
## compile model
final_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse'])

## fit the model 
final_model.fit(x_train,y_train, epochs=50, batch_size=20)
# Out:
# Epoch 1/50
# 527/527 [==============================] - 1s 548us/step - loss: 18067.4082 - mse: 18067.4082
# Epoch 2/50
# 527/527 [==============================] - 0s 565us/step - loss: 17766.7227 - mse: 17766.7227
# Epoch 3/50
# 527/527 [==============================] - 0s 557us/step - loss: 17474.0254 - mse: 17474.0254
# Epoch 4/50
# 527/527 [==============================] - 0s 692us/step - loss: 17193.3574 - mse: 17193.3574
# Epoch 5/50
# 527/527 [==============================] - 0s 839us/step - loss: 16921.8652 - mse: 16921.8652
# Epoch 6/50
# 527/527 [==============================] - 0s 578us/step - loss: 16647.3281 - mse: 16647.3281
# Epoch 7/50
# 527/527 [==============================] - 0s 552us/step - loss: 16386.8457 - mse: 16386.8457
# Epoch 8/50
# 527/527 [==============================] - 0s 554us/step - loss: 16115.2510 - mse: 16115.2510
# Epoch 9/50
# 527/527 [==============================] - 0s 565us/step - loss: 15860.3789 - mse: 15860.3789
# Epoch 10/50
# 527/527 [==============================] - 0s 548us/step - loss: 15603.5576 - mse: 15603.5576
# Epoch 11/50
# 527/527 [==============================] - 0s 550us/step - loss: 15353.1670 - mse: 15353.1670
# Epoch 12/50
# 527/527 [==============================] - 0s 559us/step - loss: 15099.2900 - mse: 15099.2900
# Epoch 13/50
# 527/527 [==============================] - 0s 558us/step - loss: 14841.5098 - mse: 14841.5098
# Epoch 14/50
# 527/527 [==============================] - 0s 546us/step - loss: 14599.7197 - mse: 14599.7197
# Epoch 15/50
# 527/527 [==============================] - 0s 567us/step - loss: 14357.4150 - mse: 14357.4150
# Epoch 16/50
# 527/527 [==============================] - 0s 574us/step - loss: 14106.9551 - mse: 14106.9551
# Epoch 17/50
# 527/527 [==============================] - 0s 559us/step - loss: 13873.8906 - mse: 13873.8906
# Epoch 18/50
# 527/527 [==============================] - 0s 559us/step - loss: 13622.8398 - mse: 13622.8398
# Epoch 19/50
# 527/527 [==============================] - 0s 559us/step - loss: 13381.5645 - mse: 13381.5645
# Epoch 20/50
# 527/527 [==============================] - 0s 594us/step - loss: 13169.0332 - mse: 13169.0332
# Epoch 21/50
# 527/527 [==============================] - 0s 876us/step - loss: 12924.3447 - mse: 12924.3447
# Epoch 22/50
# 527/527 [==============================] - 0s 879us/step - loss: 12694.4102 - mse: 12694.4102
# Epoch 23/50
# 527/527 [==============================] - 0s 852us/step - loss: 12462.8828 - mse: 12462.8828
# Epoch 24/50
# 527/527 [==============================] - 0s 576us/step - loss: 12230.0146 - mse: 12230.0146
# Epoch 25/50
# 527/527 [==============================] - 0s 567us/step - loss: 12043.6514 - mse: 12043.6514
# Epoch 26/50
# 527/527 [==============================] - 0s 556us/step - loss: 11818.1787 - mse: 11818.1787
# Epoch 27/50
# 527/527 [==============================] - 0s 561us/step - loss: 11549.1514 - mse: 11549.1514
# Epoch 28/50
# 527/527 [==============================] - 0s 559us/step - loss: 11360.9756 - mse: 11360.9756
# Epoch 29/50
# 527/527 [==============================] - 0s 572us/step - loss: 11158.2061 - mse: 11158.2070
# Epoch 30/50
# 527/527 [==============================] - 0s 561us/step - loss: 10931.1631 - mse: 10931.1631
# Epoch 31/50
# 527/527 [==============================] - 0s 566us/step - loss: 10726.2490 - mse: 10726.2490
# Epoch 32/50
# 527/527 [==============================] - 0s 561us/step - loss: 10529.1045 - mse: 10529.1045
# Epoch 33/50
# 527/527 [==============================] - 0s 578us/step - loss: 10299.8506 - mse: 10299.8506
# Epoch 34/50
# 527/527 [==============================] - 0s 603us/step - loss: 10095.4961 - mse: 10095.4951
# Epoch 35/50
# 527/527 [==============================] - 1s 980us/step - loss: 9918.1973 - mse: 9918.1963
# Epoch 36/50
# 527/527 [==============================] - 0s 921us/step - loss: 9698.9648 - mse: 9698.9648
# Epoch 37/50
# 527/527 [==============================] - 0s 584us/step - loss: 9499.3828 - mse: 9499.3828
# Epoch 38/50
# 527/527 [==============================] - 0s 571us/step - loss: 9342.3125 - mse: 9342.3125
# Epoch 39/50
# 527/527 [==============================] - 0s 561us/step - loss: 9120.4639 - mse: 9120.4639
# Epoch 40/50
# 527/527 [==============================] - 0s 559us/step - loss: 8920.6309 - mse: 8920.6309
# Epoch 41/50
# 527/527 [==============================] - 0s 563us/step - loss: 8736.5918 - mse: 8736.5918
# Epoch 42/50
# 527/527 [==============================] - 0s 582us/step - loss: 8571.7969 - mse: 8571.7979
# Epoch 43/50
# 527/527 [==============================] - 0s 563us/step - loss: 8374.6865 - mse: 8374.6865
# Epoch 44/50
# 527/527 [==============================] - 0s 561us/step - loss: 8231.0078 - mse: 8231.0078
# Epoch 45/50
# 527/527 [==============================] - 0s 571us/step - loss: 8022.9644 - mse: 8022.9644
# Epoch 46/50
# 527/527 [==============================] - 0s 644us/step - loss: 7841.5010 - mse: 7841.5010
# Epoch 47/50
# 527/527 [==============================] - 1s 968us/step - loss: 7651.0264 - mse: 7651.0264
# Epoch 48/50
# 527/527 [==============================] - 0s 882us/step - loss: 7506.9858 - mse: 7506.9858
# Epoch 49/50
# 527/527 [==============================] - 0s 630us/step - loss: 7304.8008 - mse: 7304.8008
# Epoch 50/50
# 527/527 [==============================] - 0s 563us/step - loss: 7153.2197 - mse: 7153.2197

# %%
scores = final_model.evaluate(x_test, y_test)
print((final_model.metrics_names[1]))
# Out:
# 141/141 [==============================] - 0s 456us/step - loss: 7083.7285 - mse: 7083.7285
# mse
